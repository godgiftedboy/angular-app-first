# %%
Added a p tag inside a app component and gave a red color to paragraph using element selector.

# %%
The p tag has the _ngcontent-ng-something attached to it representing the component.
The style is not leaked outside the component.
So the style associated with the app component is not applied to the paragraph outside the app component

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ng g c components/header

# %% [markdown]
# ng g c home

# %% [markdown]
# Created two components.i.e header and home component

# %% [markdown]
# ### Data binding in angular

# %% [markdown]
# Binding data between the TypeScript Class of the compoenent and the component's template.

# %% [markdown]
# Two ways for data binding:
# 1. Using signals in modern angular
# 2. Without signal (Traditional way)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Angular Routing:

# %% [markdown]
# Only load the javascript for the current page (Lazy loading javascript)

# %% [markdown]
# Here, the home compoenent is now rendering from the router outlet.
